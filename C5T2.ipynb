# %%
import pandas as pd

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
# view more of the data
credit.head(30)
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0    1      20000    2          2         1   24      2      2     -1     -1
# 1    2     120000    2          2         2   26     -1      2      0      0
# 2    3      90000    2          2         2   34      0      0      0      0
# 3    4      50000    2          2         1   37      0      0      0      0
# 4    5      50000    1          2         1   57     -1      0     -1      0
# 5    6      50000    1          1         2   37      0      0      0      0
# 6    7     500000    1          1         2   29      0      0      0      0
# 7    8     100000    2          2         2   23      0     -1     -1      0
# 8    9     140000    2          3         1   28      0      0      2      0
# 9   10      20000    1          3         2   35     -2     -2     -2     -2
# 10  11     200000    2          3         2   34      0      0      2      0
# ...

# %%
credit.tail(50)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29950  29951     220000    1          1         1   32     -1      2     -1
# 29951  29952     160000    1          1         2   30      0      0      0
# 29952  29953     210000    1          2         2   30     -1     -1     -1
# 29953  29954     170000    1          1         2   30      0      0      0
# 29954  29955     180000    1          2         2   30      0      0      0
# 29955  29956     410000    1          1         2   32     -1      2     -1
# 29956  29957     150000    1          1         2   30      0      0      0
# 29957  29958     500000    1          2         2   31      0      0     -1
# 29958  29959     230000    1          3         2   31      0     -1     -1
# 29959  29960     290000    1          1         2   32     -1     -1     -1
# 29960  29961      10000    1          2         1   29      0      0      0
# ...

# %%
# check if null values in dataframe
credit.isnull().values.any()
# Out:
# False

# %%
# Drop ID feature
credit_ready = credit.drop(['ID'], axis=1)

# %%
# Rename "default payment next month" column
credit_ready.rename(columns={'default payment next month': 'default'}, inplace=True)

# %%
# Convert sex, education, marriage, pay_0 trhough pay_5, and C to Categorical variables
credit_ready['SEX'] = credit_ready.SEX.astype('category')
credit_ready['EDUCATION'] = credit_ready.EDUCATION.astype('category')
credit_ready['MARRIAGE'] = credit_ready.MARRIAGE.astype('category')
credit_ready['PAY_0'] = credit_ready.PAY_0.astype('category')
credit_ready['PAY_2'] = credit_ready.PAY_2.astype('category')
credit_ready['PAY_3'] = credit_ready.PAY_3.astype('category')
credit_ready['PAY_4'] = credit_ready.PAY_4.astype('category')
credit_ready['PAY_5'] = credit_ready.PAY_5.astype('category')
credit_ready['PAY_6'] = credit_ready.PAY_6.astype('category')
credit_ready['default'] = credit_ready.default.astype('category')

# %%
credit_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
# LIMIT_BAL    30000 non-null int64
# SEX          30000 non-null category
# EDUCATION    30000 non-null category
# MARRIAGE     30000 non-null category
# AGE          30000 non-null int64
# PAY_0        30000 non-null category
# PAY_2        30000 non-null category
# PAY_3        30000 non-null category
# PAY_4        30000 non-null category
# PAY_5        30000 non-null category
# PAY_6        30000 non-null category
# BILL_AMT1    30000 non-null int64
# BILL_AMT2    30000 non-null int64
# BILL_AMT3    30000 non-null int64
# BILL_AMT4    30000 non-null int64
# BILL_AMT5    30000 non-null int64
# BILL_AMT6    30000 non-null int64
# PAY_AMT1     30000 non-null int64
# PAY_AMT2     30000 non-null int64
# PAY_AMT3     30000 non-null int64
# PAY_AMT4     30000 non-null int64
# PAY_AMT5     30000 non-null int64
# PAY_AMT6     30000 non-null int64
# ...

# %%
# Visualizations
import matplotlib.pyplot as plt
header = credit_ready.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default'],
#       dtype='object')

# %%
# credit limit distribution
plt.hist(credit_ready['LIMIT_BAL'],6)
plt.show()

# %%
# age distribution
plt.hist(credit_ready['AGE'],6,color = "skyblue", ec="skyblue")
plt.show()

# %%
# education status
plt.hist(credit_ready['EDUCATION'],6)
plt.show()

# %%
# credit limit line plot
plt.plot(credit_ready['LIMIT_BAL'], color='green')
plt.show()

# %%
# scatter plot
x = credit_ready['PAY_0']
y = credit_ready['PAY_2']
plt.scatter(x,y)
plt.show()

# %%
# Box plot
A = credit_ready['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
# Correlation
# The billing amount appear to correlated 
corrMat = credit_ready.corr()
print(corrMat)
# Out:
#            LIMIT_BAL       AGE  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# LIMIT_BAL   1.000000  0.144713   0.285430   0.278314   0.283236   0.293988
# AGE         0.144713  1.000000   0.056239   0.054283   0.053710   0.051353
# BILL_AMT1   0.285430  0.056239   1.000000   0.951484   0.892279   0.860272
# BILL_AMT2   0.278314  0.054283   0.951484   1.000000   0.928326   0.892482
# BILL_AMT3   0.283236  0.053710   0.892279   0.928326   1.000000   0.923969
# BILL_AMT4   0.293988  0.051353   0.860272   0.892482   0.923969   1.000000
# BILL_AMT5   0.295562  0.049345   0.829779   0.859778   0.883910   0.940134
# BILL_AMT6   0.290389  0.047613   0.802650   0.831594   0.853320   0.900941
# PAY_AMT1    0.195236  0.026147   0.140277   0.280365   0.244335   0.233012
# PAY_AMT2    0.178408  0.021785   0.099355   0.100851   0.316936   0.207564
# PAY_AMT3    0.210167  0.029247   0.156887   0.150718   0.130011   0.300023
# ...

# %%
# Covariance
covMat = credit_ready.cov()
print(covMat)
# Out:
#               LIMIT_BAL            AGE     BILL_AMT1     BILL_AMT2  \
# LIMIT_BAL  1.683446e+10  173076.722569  2.727020e+09  2.570130e+09
# AGE        1.730767e+05      84.969755  3.817293e+04  3.561366e+04
# BILL_AMT1  2.727020e+09   38172.933546  5.422240e+09  4.986670e+09
# BILL_AMT2  2.570130e+09   35613.657962  4.986670e+09  5.065705e+09
# BILL_AMT3  2.548533e+09   34334.251320  4.556511e+09  4.582086e+09
# BILL_AMT4  2.453926e+09   30453.108180  4.075286e+09  4.086508e+09
# BILL_AMT5  2.331481e+09   27654.067800  3.714795e+09  3.720401e+09
# BILL_AMT6  2.243837e+09   26137.648547  3.519876e+09  3.524868e+09
# PAY_AMT1   4.195711e+08    3992.041735  1.710894e+08  3.305146e+08
# PAY_AMT2   5.333504e+08    4626.861549  1.685692e+08  1.653859e+08
# PAY_AMT3   4.801180e+08    4746.824393  2.034048e+08  1.888731e+08
# PAY_AMT4   4.131202e+08    3087.324192  1.826164e+08  1.643518e+08
# PAY_AMT5   4.305657e+08    3218.052172  1.879091e+08  1.717652e+08
# ...

# %%
# Nunmber of creditholders by gender -  majority female
credit_ready.groupby('SEX')['SEX'].count()
# Out:
# SEX
# 1    11888
# 2    18112
# Name: SEX, dtype: int64

# %%
# Number of clients by marriage status - large majority with at least University level
credit_ready.groupby('MARRIAGE')['MARRIAGE'].count()
# Out:
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# Name: MARRIAGE, dtype: int64

# %%
# Repayment status for the most recent month - Over 6000 crediholders with payment delay of at least 1 month
import seaborn as sns
fg = sns.factorplot('PAY_0', data=credit_ready, kind='count', aspect=1.5)
fg.set_xlabels('PAY_0')

# %%
# Default status by gender - sligthly larger percentage of male in default
g = sns.factorplot('SEX', data=credit_ready, hue='default', kind='count', aspect=1.75)
g.set_xlabels('SEX')

# %%
# Default status by marriage 
h = sns.factorplot('MARRIAGE', data=credit_ready, hue='default', kind='count', aspect=1.75)
h.set_xlabels('MARRIAGE')

# %%
# Age distribution with seaborn -  Majority within 20 and 40 years
age = credit_ready['AGE']
age_dist = sns.distplot(age)
age_dist.set_title("Distribution of Creditholders' Ages")
# Out:
# Text(0.5,1,"Distribution of Creditholders' Ages")

# %%
# Distribution of age by gender -  both men and women have similar distribution
fig = sns.FacetGrid(credit_ready, hue='SEX', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit_ready['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Gender')
fig.add_legend()

# %%
# number of married and single women in default is about equal. Same for men
table = pd.crosstab(index=[credit_ready.default], columns=[credit_ready.SEX,credit_ready.MARRIAGE])
table.columns.set_levels(['Female', 'Male'], level=0, inplace=True)
table.columns.set_levels(['Others','Married', 'Single','Divorced'], level=1, inplace=True)

table
# Out:
# SEX      Female                           Male
# MARRIAGE Others Married Single Divorced Others Married Single Divorced
# default
# 0            12    3844   5068       91     37    6609   7555      148
# 1             2    1346   1485       40      3    1860   1856       44

# %%
# Education factorplot
sns.factorplot('EDUCATION', data=credit_ready, kind='count',  aspect=2, 
              palette='winter_d')

# %%
# Age vs credit Limit - relationship not linear
# Linear plot of age vs. survived
sns.lmplot('AGE', 'LIMIT_BAL', data=credit_ready)
